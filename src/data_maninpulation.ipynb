# %%
import pandas as pd

# %%
raw_data = pd.read_csv("data/ks2_results_data.csv")

# %%
raw_data
# Out:
#      Unnamed: 0                                            SCHNAME  RECTYPE  \
# 0             0                      Drapers Mills Primary Academy        1
# 1             1                            Richmond Primary School        1
# 2             2                St Edward's Catholic Primary School        1
# 3             3             St Ethelbert's Catholic Primary School        1
# 4             4                                Copperfield Academy        1
# ..          ...                                                ...      ...
# 345         345  St Margaret's, Collier Street Church of Englan...        1
# 346         346  Lady Boswell's Church of England Voluntary Aid...        1
# 347         347  Chevening, St Botolph's Church of England Volu...        1
# 348         348       Our Lady's Catholic Primary School, Dartford        1
# 349         349                                  Lukes test school        1
#
#      ALPHAIND    LEA   ESTAB       URN  \
# ...

# %%
raw_data["school_id"] = raw_data.index

# %%
raw_data.to_csv("data/ks2_results_data.csv")
