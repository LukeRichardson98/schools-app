# %%
import pandas as pd

# %%
df = pd.read_csv("data/ks2_results_data.csv")

# %%
df
# Out:
#                                                SCHNAME  RECTYPE  ALPHAIND  \
# 0                        Drapers Mills Primary Academy        1   16974.0
# 1                              Richmond Primary School        1   46838.0
# 2                  St Edward's Catholic Primary School        1   50454.0
# 3               St Ethelbert's Catholic Primary School        1   50542.0
# 4                                  Copperfield Academy        1   14118.0
# ..                                                 ...      ...       ...
# 345  St Margaret's, Collier Street Church of Englan...        1   52838.0
# 346  Lady Boswell's Church of England Voluntary Aid...        1   31810.0
# 347  Chevening, St Botolph's Church of England Volu...        1   12030.0
# 348       Our Lady's Catholic Primary School, Dartford        1   42420.0
# 349                                  Lukes test school        1   52720.0
#
#        LEA   ESTAB       URN  \
# 0    886.0  2017.0  139021.0
# ...

# %%
# Adding an 'id' column starting from 1
df["SchoolID"] = range(0, len(df))

# %%
df["SchoolID"]
# Out:
# 0        0
# 1        1
# 2        2
# 3        3
# 4        4
#       ...
# 345    345
# 346    346
# 347    347
# 348    348
# 349    349
# Name: SchoolID, Length: 350, dtype: int64

# %%
df.to_csv("data/ks2_results_data.csv")
